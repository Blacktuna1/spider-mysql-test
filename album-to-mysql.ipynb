# %%
# 连接到MySQL数据库
# 24-3-getfrom163
connection = pymysql.connect(host='localhost',user='root',password='123456',database='24-3-getfrom163',charset='utf8mb4',cursorclass=pymysql.cursors.DictCursor)

try:
    # 执行SQL查询
    with connection.cursor() as cursor:
        sql = "SELECT * FROM artists"
        cursor.execute(sql)
        result = cursor.fetchall()

        # 将查询结果转换为DataFrame
        df = pd.DataFrame(result)

finally:
    # 关闭数据库连接
    connection.close()

# %%
import pymysql
import pandas as pd

# %%
df.to_csv(r"C:\Users\10378\Desktop\artist.csv", index=False, encoding='utf-8-sig')

# %%
df.to_csv(r"C:\Users\10378\Desktop\books.csv", index=False, encoding='utf-8-sig')

# %%
books8 = pd.read_csv(r"C:\Users\10378\Desktop\books.csv")

# %%
books8
# Out:
#             BookID                                          BookTitle  \
# 0       0195153448                                    Happy.Birth.Day
# 1       0002005018                                                你最牛
# 2       0060973129                                            天天天天说爱你
# 3       0374157065                                              桃花朵朵开
# 4       0393045218                                              无尾熊抱抱
# ...            ...                                                ...
# 264696  0440400988             Serenity Ignited: Ember Yoga Harmonies
# 264697  0525447644                                              漆黑的月光
# 264698  006008667X                                            大世界小小的我
# 264699  0192126040                                               喜欢雨天
# 264700  0767409752  Harmonic Thunder Pulsations: Focused Musical S...
#
#                   BookAuthor PubilcationYear  \
# 0         Mark P. O. Morford       2006.2.01
# ...

# %% [markdown]
# ### 将表导入到mysql

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

# 建立到MySQL数据库的连接
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/book')

# 将DataFrame写入MySQL数据库的表
table_name = 'books'
books8.to_sql(name=table_name, con=engine, if_exists='replace', index=False)

# 关闭数据库连接
engine.dispose()
